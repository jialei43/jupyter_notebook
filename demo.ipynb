# %% [markdown]
# # 我是无敌一生
# - 你是谁,我是你爸爸

# %% [markdown]
# ```python
# print("hello world")
# import numpy as np
# a = np.array([1,2,3])
# print(a)
# ```
# - 这是一个基础类型

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
import numpy as np
a = np.array([1,2,3])
print(a)
# Out:
# [1 2 3]
